# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
# Import the libraries you'll need here.
import pandas as pd
import numpy as np

# A basic visualization library
import matplotlib.pyplot as plt

# A great visualization library
import seaborn as sns
# This command tells python to use seaborn for its styling.
sns.set()

# Very important, this will make your charts appear in your notebook instead of in a new window.
# %matplotlib inline

import scipy.stats as stats

# %% [markdown]
# # Load the csv file into a pandas dataframe.

# %%
# Load the csv file into a pandas dataframe.
df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicated().sum())
# Out:
# 720

# %%
#  2. Modify our df to have all duplicate rows removed. 
df = df.drop_duplicates()

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?
df.isnull().sum().sort_values(ascending=False).head(1)
# Out:
# Engine HP    69
# dtype: int64

# %%
# * Print how long (aka how many rows) our dataframe is.
print(df.shape[0], len(df))
# Out:
# 11194 11194

# %%
# * Remove any row that has a null value in it. 
df = df.dropna()

# %%
# * Do a sanity check and print how long our dataframe is now that we have removed our null values.
print(df.shape[0], len(df))
# Out:
# 11092 11092

# %% [markdown]
# ### Make a bar chart that displays how many time each brand of car appears in this data.
# _Brand of car is the `Make` of the car._

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 
make_counts = df['Make'].value_counts()
make_counts.plot(kind='bar', figsize=(15,5))

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.

# %%
# Make the cart more legible, by making it a horizontal bar chart and changing the figure size.
make_counts.plot(kind="barh", figsize=(13,13))

# %% [markdown]
# ### Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
average_MSRP = df.groupby('Year')['MSRP'].mean()
average_MSRP.plot()

# %% [markdown]
# # It seems as though in the years before 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for
# every year before 2000 make it 10x the original MSRP.

# %%
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
df['price_adjuster'] =  np.where(df['Year'] <= 2000, 10, 1)
df['adjusted_price'] =  df['MSRP'] * df['price_adjuster']
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# ...

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Replot the new adjusted price and make the y-axis start at 0 and go up to 100,000
prices = df.groupby('Year')['adjusted_price'].mean()
prices.plot(ylim=(0, 80000))

# %% [markdown]
# # What are the top 5 car makers make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5.
# * Use our `adjusted_price` column for this

# %%
# What are the top 5 car makers make the most expensive cars on average. 
df.groupby('Make')['adjusted_price'].mean().round(3).sort_values(ascending=False).head(5)
# Out:
# Make
# Bugatti        1757223.667
# Maybach         546221.875
# Rolls-Royce     351130.645
# Lamborghini     331567.308
# Bentley         247169.324
# Name: adjusted_price, dtype: float64

# %% [markdown]
# # What are the top 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?
df.groupby('Make')['highway MPG'].median().sort_values(ascending=False).head(5)
# Out:
# Make
# Alfa Romeo    34
# FIAT          33
# Volkswagen    32
# Scion         32
# Honda         32
# Name: highway MPG, dtype: int64

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
plt.figure(figsize=(13,8))
my_list = ['Chevrolet', 'Ford', 'Toyota']
tmp_df = df[df.Make.isin(my_list)]
sns.histplot(data=tmp_df, x='adjusted_price', hue='Make')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-2cc954fcb65c> in <module>
#       3 my_list = ['Chevrolet', 'Ford', 'Toyota']
#       4 tmp_df = df[df.Make.isin(my_list)]
# ----> 5 sns.histplot(data=tmp_df, x='adjusted_price', hue='Make')
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000
ax = sns.histplot(data=tmp_df, x='adjusted_price', hue='Make')
ax.set_xlim(0, 100000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-52cc20ef6a3b> in <module>
#       1 # Remake the same histogram, but limit the x-axis from 0 to 100,000
# ----> 2 ax = sns.histplot(data=tmp_df, x='adjusted_price', hue='Make')
#       3 ax.set_xlim(0, 100000)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG
df.plot(kind='scatter', x='Engine HP', y='highway MPG')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Remove any statisical outliers from Engine HP and highway MPG and plot the result.
# * Statisical outliers meaning values that are further than 3 standard deviations from the mean
# * Create a new columns for z-scores for each 'Engine HP' and 'highway MPG' named 'Engine HP_zscore' and 'highway MPG_zscore'
# * Calculate the z-scores for each of our target columns.
# * Make sure you set the z-scores to be their absolute values.
# * Create condition masks for when either of those absolute values are greater than 3.
#
# * Create a new dataframe that is a copy of our dataframe using df.copy()
#
# * Using our new dataframe
#     * Filter out all Engine HP Z-Scores that are greater than 3
#     * Filter out all Highway MPG z-scores that are greater than 3.
#     * Make the same scatterplot plotting the relationship of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any statisical outliers from Engine HP and highway MPG

# Make a list of the columns we want to find z-scores for
target_cols = ['Engine HP', 'highway MPG']


# Loop through our target columns
for col in target_cols:
    # Make the new column name the same as the original but with 'z_score' added to it
    new_col_name = col + "_zscore"
    
    # Set the new column equal to the score
    df[new_col_name] = stats.stats.zscore( df[col] )
    
    # Set the z-score to its absolute value of the for easier filtering
    df[new_col_name] = abs(df[new_col_name])
    
# # Select where the zscore is less than three    
c1 = df['Engine HP_zscore'] < 3

# # Select where the zscore is less than three    
c2 = df['highway MPG_zscore'] < 3

# # Make a new dataframe where either z-scores are less than 3
new_df = df.copy()

new_df = new_df[c1]

new_df = new_df[c2]

# Make a scatter plot of the HP and MPG
new_df.plot(kind='scatter', x='Engine HP', y='highway MPG')
# Out:
# <ipython-input-30-56e7647bb0e7>:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df = new_df[c2]
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?
plt.figure(figsize=(21,13))
sns.regplot(data=df[c1 & c2], x="Engine HP", y="highway MPG")
print('It tells us that the higher the Engine HP, the less highway MPG the car will get.')
# Out:
# It tells us that the higher the Engine HP, the less highway MPG the car will get.

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
sns.pairplot(data=new_df);

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).
print('city MPG', 'and', 'highway MPG')
sns.regplot(data=new_df, x="highway MPG", y="city mpg").set_xlim(left=0,right=100)
# Out:
# city MPG and highway MPG
# (0.0, 100.0)

# %%
sns.regplot(data=new_df, x="MSRP", y="Engine HP").set_xlim(left=0,right=500000)
# Out:
# (0.0, 500000.0)

# %%
sns.regplot(data=new_df, x="Engine Cylinders", y="Engine HP")

# %%
sns.regplot(data=new_df, x="Engine HP", y="city mpg")

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
plt.figure(figsize=(8,8))
ax = sns.heatmap(new_df.corr(), annot=True, cmap='Spectral')

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
# * Using subplots, display the histogram of adjusted_price for 'Ford' and 'Toyota' appear on charts side by side.
#     * `f, axes = plt.subplots(1, 2, figsize=(13,5))`

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
for col in new_df.columns:
    new_df.rename(columns = {col: col.lower().replace(" ","_")} , inplace=True)
    
fig, ax = plt.subplots(1,2, figsize=(13,5))

# %%
sns.histplot(data = new_df[ new_df['make'].isin(["Ford"]) ]["adjusted_price"], ax=ax[0])
sns.histplot(data = new_df[ new_df['make'].isin(["Toyota"]) ]["adjusted_price"], ax=ax[1])
ax[0].title.set_text('Ford')
ax[1].title.set_text('Toyota')
fig.show()

new_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-7e6eb90a8a78> in <module>
# ----> 1 sns.histplot(data = new_df[ new_df['make'].isin(["Ford"]) ]["adjusted_price"], ax=ax[0])
#       2 sns.histplot(data = new_df[ new_df['make'].isin(["Toyota"]) ]["adjusted_price"], ax=ax[1])
#       3 ax[0].title.set_text('Ford')
#       4 ax[1].title.set_text('Toyota')
#       5 fig.show()
#
# AttributeError: module 'seaborn' has no attribute 'histplot'
